# %%
import files
import os

Nmodes = [2,4,6,8,10,15,20,25,30,35,40]
executable = "22collocation_U"
for i in Nmodes:
    files.sed_variable("NmodesTproj","system/ITHACAdict",i)
    os.system(executable)
    os.system("rm -r ITHACAoutput")
# Out:
# /*---------------------------------------------------------------------------*\
# | =========                 |                                                 |
# | \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox           |
# |  \\    /   O peration     | Version:  2212                                  |
# |   \\  /    A nd           | Website:  www.openfoam.com                      |
# |    \\/     M anipulation  |                                                 |
# \*---------------------------------------------------------------------------*/
# Build  : _66908158ae-20221220 OPENFOAM=2212 version=v2212
# Arch   : "LSB;label=32;scalar=64"
# Exec   : 22collocation_U
# Date   : Feb 13 2023
# Time   : 15:31:32
# Host   : giova-pc
# PID    : 50786
# I/O    : uncollated
# Case   : /home/giova/OpenFOAM/ITHACA-FV/tutorials/CFD/22collocation_U
# nProcs : 1
# trapFpe: Floating point exception trapping enabled (FOAM_SIGFPE).
# ...
