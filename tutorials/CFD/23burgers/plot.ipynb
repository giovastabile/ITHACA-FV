# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
gal = np.load("erGal.npy")
colU = np.load("erCol_U.npy")
colRU = np.load("erCol_RU.npy")

# %%
plt.plot(gal, "--", marker='o', markevery=10, label='Gal')
plt.plot(colU, "-", marker='*', markevery=10, label='ColU')
plt.plot(colRU, "-", marker='', markevery=10, label='ColR')
plt.legend()
